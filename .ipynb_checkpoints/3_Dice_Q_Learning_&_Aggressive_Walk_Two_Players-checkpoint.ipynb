# %% [markdown]
# ## **First install ludopy and Q-Learner Trained Agent**
#
# ---

# %%
# !git clone https://github.com/arindammajee/A-Reinforcement-Learning-Approach-to-Ludo.git  # Q-Learning Trained Agent
# Out:
# Cloning into 'A-Reinforcement-Learning-Approach-to-Ludo'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 131 (delta 8), reused 13 (delta 5), pack-reused 112
# Receiving objects: 100% (131/131), 7.71 MiB | 27.32 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %% [markdown]
# ## Import ludopy and some others

# %%
import sys
import os
import numpy as np
import cv2
import time
import matplotlib.pyplot as plt
from IPython.display import clear_output

# Now import LudoPy and Q-Learn Trained Agent
dir="/content/A-Reinforcement-Learning-Approach-to-Ludo/LUDOpy"
qlearn_dir = '/'.join(dir.split('/')[:-1])
sys.path.append(os.path.abspath(dir))
sys.path.append(os.path.abspath(os.path.join(qlearn_dir, 'src')))
import ludopy
from Qlearn import Qplayer

# %% [markdown]
# ## Strategy and GUI Define

# %%
def strategy(pieces_that_can_move, player_pieces, enemy_pieces, dice):
  safe_positions = [1, 5, 12, 18, 25]
  move_piece = -1
  if len(pieces_that_can_move)==0:
    return move_piece

  # Distance positions of enemy pieces
  distance_enemy_pieces = enemy_pieces[1] - 27

  # Promoting a token
  if move_piece==-1:
    for piece in pieces_that_can_move:
      if player_pieces[piece] + dice == 57:
        move_piece = piece
        return move_piece

  # Capture opponent
  if move_piece==-1:
    for piece in pieces_that_can_move:
      for enemy_pos in distance_enemy_pieces:
        dist = enemy_pos - player_pieces[piece]
        # Check if you can kill enemy
        if dist == dice:
          move_piece = piece
          return move_piece

  # Moving Token to a Safe Square
  if move_piece==-1:
    for piece in pieces_that_can_move:
      future_pos = player_pieces[piece] + dice
      if future_pos in safe_positions:
        move_piece = piece
        return move_piece

  # Moving the first piece
  if move_piece==-1:
    max_piece, max_dist = -1, -1
    for piece in pieces_that_can_move:
      if player_pieces[piece] > max_dist:
        max_piece = piece
        max_dist = player_pieces[piece]

    move_piece = max_piece
    return move_piece

  return move_piece


def gui_on(game, FIGURE_SIZE, SLEEP_TIME):
  enviroment_image_rgb = game.render_environment()  # RGB image of the enviroment
  #enviroment_image_bgr = cv2.cvtColor(enviroment_image_rgb, cv2.COLOR_RGB2BGR)
  clear_output(wait=True)
  figure = plt.figure(figsize=FIGURE_SIZE)
  plt.imshow(enviroment_image_rgb)
  plt.show()
  time.sleep(SLEEP_TIME)

# %% [markdown]
# ## SETUP GLOBAL VARIABLES FOR GAMES SIMULATION

# %%
#####################################################################################################
## SETUP GLOBAL VARIABLES FOR GAMES SIMULATION
NUM_PLAYERS = 2 # Or 4
GUI = False
FIGURE_SIZE = (9.6, 7.2)  #In Inches. Try to keep the aspect ratio in 4:3
SLEEP_TIME = 2 # In Second. Wait time between two moves proper visualization
GAME_LENGTH = 10 #"FULL" # 24 or 36 or "FULL"

player_color_dict = {
    0: "GREEN (Bottom Left)",
    1: "YELLOW (Top Left)",
    2: "BLUE (Top Right)",
    3: "RED (Bottom Right)"
}
#####################################################################################################

# %% [markdown]
# ## GAME Simulation Testing Function

# %%
## Simulation Testing Function
def GameSimulation(run_num=1, num_round=GAME_LENGTH, print_each_result=False, game_type=0, gui=False, figure_size=FIGURE_SIZE, wait_time=SLEEP_TIME, save_hist=False):
  player_2_type = {
    0: "Random Player",
    1: "Q-Learner Player"
  }
  print(f"We will simulate {run_num} game each for {num_round} rounds. These games will be Aggressive player vs {player_2_type[game_type]}")
  print(f"Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is {player_2_type[game_type]}")


  ## Winners List
  winners =[]
  start_time = time.time()

  for run in range(run_num):
    ## GAME Setup
    if NUM_PLAYERS==2:
      g = ludopy.Game(ghost_players=[1, 3])  # This will prevent players 1 and 3 from moving out of the start and thereby they are not in the game
    else:
      g = ludopy.Game()
    if game_type==1:
      player2 = Qplayer(tableName=os.path.join(qlearn_dir, 'src/Qs.txt'))

    there_is_a_winner = False
    while not there_is_a_winner:
      (dice, move_pieces, player_pieces, enemy_pieces, player_is_a_winner, there_is_a_winner), player_i = g.get_observation()
        #print(f"{player_i}: {dice}, {move_pieces}  {player_pieces}")
      if gui:
        gui_on(game=g, FIGURE_SIZE=figure_size, SLEEP_TIME=wait_time)

      if player_i==0:
        piece_to_move = strategy(move_pieces, player_pieces, enemy_pieces, dice)
      elif player_i==2:
        if game_type==0:
          if len(move_pieces):
            piece_to_move = move_pieces[np.random.randint(0, len(move_pieces))]
          else:
            piece_to_move = -1
        elif game_type==1:
          player2.nextmove(player_i, player_pieces, enemy_pieces, dice, move_pieces)
          piece_to_move = player2.piece

      _, _, _, _, _, there_is_a_winner = g.answer_observation(piece_to_move)

      if there_is_a_winner and GUI:
        gui_on(game=g, FIGURE_SIZE=FIGURE_SIZE, SLEEP_TIME=SLEEP_TIME)

      if num_round!="FULL":
        if g.hist[-1][-1]==num_round+1:
          break

    winner = g.get_winner_of_game()
    if winner==-1:
      points_list = g.points_list
      winner = points_list.index(max(points_list))

    if print_each_result:
      print(f"Winner is: Player-{winner} {player_color_dict[winner]}")
    if save_hist:
      print("Saving history to numpy file")
      g.save_hist(f"game_history_random.npy")
      print("Saving game video")
      g.save_hist_video(f"game_video_random.mp4")

    winners.append(winner)

  end_time = time.time()
  total_time = end_time - start_time
  print(f"No of Rounds: {num_round}, No of runs: {run_num}, Total time: {total_time:.3f} sec, Average time: {total_time/run_num:.3f} sec")
  aggressive_win, player2_winn = winners.count(0), winners.count(2)
  print(f"Aggressive won {aggressive_win} games out of {run_num} games. Winning percentage is: {aggressive_win/run_num:.3f}")
  print(f"{player_2_type[game_type]} won {player2_winn} games out of {run_num} games. Winning percentage is: {player2_winn/run_num:.3f}")
  return winners, player2_winn/run_num

# %%
 GameSimulation(run_num=1, num_round=GAME_LENGTH, print_each_result=False, game_type=0, gui=True, figure_size=FIGURE_SIZE, wait_time=SLEEP_TIME, save_hist=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-177f6e2620ec> in <cell line: 1>()
# ----> 1 GameSimulation(run_num=1, num_round=GAME_LENGTH, print_each_result=False, game_type=0, gui=True, figure_size=FIGURE_SIZE, wait_time=SLEEP_TIME, save_hist=False)
#
# <ipython-input-7-4162868e3dee> in GameSimulation(run_num, num_round, print_each_result, game_type, gui, figure_size, wait_time, save_hist)
#      27         #print(f"{player_i}: {dice}, {move_pieces}  {player_pieces}")
#      28       if gui:
# ---> 29         gui_on(game=g, FIGURE_SIZE=figure_size, SLEEP_TIME=wait_time)
#      30
#      31       if player_i==0:
#
# <ipython-input-3-f76e16d71512> in gui_on(game, FIGURE_SIZE, SLEEP_TIME)
#      54   plt.imshow(enviroment_image_rgb)
#      55   plt.show()
# ---> 56   time.sleep(SLEEP_TIME)
#
# KeyboardInterrupt:

# %% [markdown]
# ## **Aggressive vs Q-Learning Win Percentage Determination**

# %%
##########################################################################
## Play The GAME
##########################################################################
GUI = False
FIGURE_SIZE = (9.6, 7.2)  #In Inches. Try to keep the aspect ratio in 4:3
SLEEP_TIME = 2 # In Second. Wait time between two moves proper visualization
GAME_LENGTH = 12 #"FULL" # 24 or 36 or "FULL"

QWIN_PERCENTAGE_LIST = []
for i in range(1, 31):
  print(f"####################################### NUM_ROUNDS={i} #######################################")
  winners, qwin_per = GameSimulation(run_num=1000, num_round=i, print_each_result=False, game_type=1)
  QWIN_PERCENTAGE_LIST.append(qwin_per)
  print("\n")
# Out:
# ####################################### NUM_ROUNDS=1 #######################################
# We will simulate 1000 game each for 1 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 1, No of runs: 1000, Total time: 4.201 sec, Average time: 0.004 sec
# Aggressive won 729 games out of 1000 games. Winning percentage is: 0.729
# Q-Learner Player won 271 games out of 1000 games. Winning percentage is: 0.271
#
#
# ####################################### NUM_ROUNDS=2 #######################################
# We will simulate 1000 game each for 2 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 2, No of runs: 1000, Total time: 5.015 sec, Average time: 0.005 sec
# Aggressive won 587 games out of 1000 games. Winning percentage is: 0.587
# Q-Learner Player won 413 games out of 1000 games. Winning percentage is: 0.413
#
#
# ####################################### NUM_ROUNDS=3 #######################################
# We will simulate 1000 game each for 3 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 3, No of runs: 1000, Total time: 9.370 sec, Average time: 0.009 sec
# Aggressive won 518 games out of 1000 games. Winning percentage is: 0.518
# Q-Learner Player won 482 games out of 1000 games. Winning percentage is: 0.482
#
#
# ####################################### NUM_ROUNDS=4 #######################################
# We will simulate 1000 game each for 4 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 4, No of runs: 1000, Total time: 13.554 sec, Average time: 0.014 sec
# Aggressive won 459 games out of 1000 games. Winning percentage is: 0.459
# Q-Learner Player won 541 games out of 1000 games. Winning percentage is: 0.541
#
#
# ####################################### NUM_ROUNDS=5 #######################################
# We will simulate 1000 game each for 5 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 5, No of runs: 1000, Total time: 21.446 sec, Average time: 0.021 sec
# Aggressive won 390 games out of 1000 games. Winning percentage is: 0.390
# Q-Learner Player won 610 games out of 1000 games. Winning percentage is: 0.610
#
#
# ####################################### NUM_ROUNDS=6 #######################################
# We will simulate 1000 game each for 6 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 6, No of runs: 1000, Total time: 26.328 sec, Average time: 0.026 sec
# Aggressive won 288 games out of 1000 games. Winning percentage is: 0.288
# Q-Learner Player won 712 games out of 1000 games. Winning percentage is: 0.712
#
#
# ####################################### NUM_ROUNDS=7 #######################################
# We will simulate 1000 game each for 7 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 7, No of runs: 1000, Total time: 32.357 sec, Average time: 0.032 sec
# Aggressive won 284 games out of 1000 games. Winning percentage is: 0.284
# Q-Learner Player won 716 games out of 1000 games. Winning percentage is: 0.716
#
#
# ####################################### NUM_ROUNDS=8 #######################################
# We will simulate 1000 game each for 8 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 8, No of runs: 1000, Total time: 38.604 sec, Average time: 0.039 sec
# Aggressive won 239 games out of 1000 games. Winning percentage is: 0.239
# Q-Learner Player won 761 games out of 1000 games. Winning percentage is: 0.761
#
#
# ####################################### NUM_ROUNDS=9 #######################################
# We will simulate 1000 game each for 9 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 9, No of runs: 1000, Total time: 44.684 sec, Average time: 0.045 sec
# Aggressive won 205 games out of 1000 games. Winning percentage is: 0.205
# Q-Learner Player won 795 games out of 1000 games. Winning percentage is: 0.795
#
#
# ####################################### NUM_ROUNDS=10 #######################################
# We will simulate 1000 game each for 10 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 10, No of runs: 1000, Total time: 52.684 sec, Average time: 0.053 sec
# Aggressive won 181 games out of 1000 games. Winning percentage is: 0.181
# Q-Learner Player won 819 games out of 1000 games. Winning percentage is: 0.819
#
#
# ####################################### NUM_ROUNDS=11 #######################################
# We will simulate 1000 game each for 11 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 11, No of runs: 1000, Total time: 59.964 sec, Average time: 0.060 sec
# Aggressive won 151 games out of 1000 games. Winning percentage is: 0.151
# Q-Learner Player won 849 games out of 1000 games. Winning percentage is: 0.849
#
#
# ####################################### NUM_ROUNDS=12 #######################################
# We will simulate 1000 game each for 12 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 12, No of runs: 1000, Total time: 75.392 sec, Average time: 0.075 sec
# Aggressive won 122 games out of 1000 games. Winning percentage is: 0.122
# Q-Learner Player won 878 games out of 1000 games. Winning percentage is: 0.878
#
#
# ####################################### NUM_ROUNDS=13 #######################################
# We will simulate 1000 game each for 13 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 13, No of runs: 1000, Total time: 78.852 sec, Average time: 0.079 sec
# Aggressive won 112 games out of 1000 games. Winning percentage is: 0.112
# Q-Learner Player won 888 games out of 1000 games. Winning percentage is: 0.888
#
#
# ####################################### NUM_ROUNDS=14 #######################################
# We will simulate 1000 game each for 14 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 14, No of runs: 1000, Total time: 83.038 sec, Average time: 0.083 sec
# Aggressive won 100 games out of 1000 games. Winning percentage is: 0.100
# Q-Learner Player won 900 games out of 1000 games. Winning percentage is: 0.900
#
#
# ####################################### NUM_ROUNDS=15 #######################################
# We will simulate 1000 game each for 15 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 15, No of runs: 1000, Total time: 89.742 sec, Average time: 0.090 sec
# Aggressive won 90 games out of 1000 games. Winning percentage is: 0.090
# Q-Learner Player won 910 games out of 1000 games. Winning percentage is: 0.910
#
#
# ####################################### NUM_ROUNDS=16 #######################################
# We will simulate 1000 game each for 16 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 16, No of runs: 1000, Total time: 97.017 sec, Average time: 0.097 sec
# Aggressive won 78 games out of 1000 games. Winning percentage is: 0.078
# Q-Learner Player won 922 games out of 1000 games. Winning percentage is: 0.922
#
#
# ####################################### NUM_ROUNDS=17 #######################################
# We will simulate 1000 game each for 17 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 17, No of runs: 1000, Total time: 104.002 sec, Average time: 0.104 sec
# Aggressive won 58 games out of 1000 games. Winning percentage is: 0.058
# Q-Learner Player won 942 games out of 1000 games. Winning percentage is: 0.942
#
#
# ####################################### NUM_ROUNDS=18 #######################################
# We will simulate 1000 game each for 18 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 18, No of runs: 1000, Total time: 110.476 sec, Average time: 0.110 sec
# Aggressive won 51 games out of 1000 games. Winning percentage is: 0.051
# Q-Learner Player won 949 games out of 1000 games. Winning percentage is: 0.949
#
#
# ####################################### NUM_ROUNDS=19 #######################################
# We will simulate 1000 game each for 19 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 19, No of runs: 1000, Total time: 116.785 sec, Average time: 0.117 sec
# Aggressive won 42 games out of 1000 games. Winning percentage is: 0.042
# Q-Learner Player won 958 games out of 1000 games. Winning percentage is: 0.958
#
#
# ####################################### NUM_ROUNDS=20 #######################################
# We will simulate 1000 game each for 20 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# No of Rounds: 20, No of runs: 1000, Total time: 128.946 sec, Average time: 0.129 sec
# Aggressive won 35 games out of 1000 games. Winning percentage is: 0.035
# Q-Learner Player won 965 games out of 1000 games. Winning percentage is: 0.965
#
#
# ####################################### NUM_ROUNDS=21 #######################################
# We will simulate 1000 game each for 21 rounds. These games will be Aggressive player vs Q-Learner Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Q-Learner Player
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-ab854f6f66cd> in <cell line: 10>()
#      10 for i in range(1, 31):
#      11   print(f"####################################### NUM_ROUNDS={i} #######################################")
# ---> 12   winners, qwin_per = GameSimulation(run_num=1000, num_round=i, print_each_result=False, game_type=1)
#      13   QWIN_PERCENTAGE_LIST.append(qwin_per)
#      14   print("\n")
#
# <ipython-input-7-4162868e3dee> in GameSimulation(run_num, num_round, print_each_result, game_type, gui, figure_size, wait_time, save_hist)
#      38             piece_to_move = -1
#      39         elif game_type==1:
# ---> 40           player2.nextmove(player_i, player_pieces, enemy_pieces, dice, move_pieces)
#      41           piece_to_move = player2.piece
#      42
#
# /content/A-Reinforcement-Learning-Approach-to-Ludo/src/Qlearn.py in nextmove(self, player_i, player_pieces, enemy_pieces, dice, move_pieces)
#      62
#      63     def nextmove(self, player_i, player_pieces, enemy_pieces, dice, move_pieces):
# ---> 64         self.piece, self.action, self.state = self.map2gamespace(player_i, player_pieces,
#      65                                                                  enemy_pieces, dice, move_pieces)
#      66
#
# /content/A-Reinforcement-Learning-Approach-to-Ludo/src/Qlearn.py in map2gamespace(self, player_id, player_pieces, enemy_pieces, dice, active_pieces)
#     135         for i in range(0, num_pieces):
#     136             i = active_pieces[i]
# --> 137             possiblevec = self.possiblemoves(player_pieces[i], player_pieces, enemy_pieces, dice)
#     138             state[i] = self.findstate(i, possiblevec, player_pieces,enemy_pieces)
#     139
#
# /content/A-Reinforcement-Learning-Approach-to-Ludo/src/Qlearn.py in possiblemoves(self, current_piece, player_pieces, enemy, dice)
#     177                  [59]]
#     178
# --> 179         adj_enemy = self.adjustenemy(enemy)
#     180
#     181         if current_piece != 0:
#
# /content/A-Reinforcement-Learning-Approach-to-Ludo/src/Qlearn.py in adjustenemy(self, enemy)
#     165         for i in range(enemy.shape[0]):
#     166             for j in range(enemy.shape[1]):
# --> 167                 if (enemy[i, j] != 0) & (enemy[i, j] < 54):
#     168                     adj_enemy[i, j] = enemy[i, j] + (i + 1) * 13
#     169                     if (adj_enemy[i, j] / 53) >= 1:
#
# KeyboardInterrupt:

# %%
rounds = np.arange(1, 31)
winning_percentage_qlearner = QWIN_PERCENTAGE_LIST
winning_percentage_aggressive = [1 - percentage for percentage in QWIN_PERCENTAGE_LIST]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(rounds, winning_percentage_qlearner)
ax[0].set_title("No of Rounds vs Winning percentage of Q-Learner Player")
ax[0].set_xlabel("No of Rounds")
ax[0].set_ylabel("Winning percentage of Q-Learner Player")

ax[1].plot(rounds, winning_percentage_aggressive)
ax[1].set_title("No of Rounds vs Winning percentage of Aggressive Player")
ax[1].set_xlabel("No of Rounds")
ax[1].set_ylabel("Winning percentage of Aggressive Player")
# Out:
# Text(0, 0.5, 'Winning percentage of Strategic Player')

# %% [markdown]
# ## **Aggressive vs Random Win Percentage Determination**

# %%
##########################################################################
## Play The GAME
##########################################################################
GUI = False
FIGURE_SIZE = (9.6, 7.2)  #In Inches. Try to keep the aspect ratio in 4:3
SLEEP_TIME = 2 # In Second. Wait time between two moves proper visualization
GAME_LENGTH = 12 #"FULL" # 24 or 36 or "FULL"

RANDOM_PERCENTAGE_LIST = []
for i in range(1, 31):
  print(f"####################################### NUM_ROUNDS={i} #######################################")
  winners, ranwin_per = GameSimulation(run_num=2000, num_round=i, print_each_result=False, game_type=0)
  RANDOM_PERCENTAGE_LIST.append(ranwin_per)
  print("\n")
# Out:
# ####################################### NUM_ROUNDS=1 #######################################
# We will simulate 2000 game each for 1 rounds. These games will be Aggressive player vs Random Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Random Player
# No of Rounds: 1, No of runs: 2000, Total time: 1.425 sec, Average time: 0.001 sec
# Aggressive won 1525 games out of 2000 games. Winning percentage is: 0.762
# Random Player won 475 games out of 2000 games. Winning percentage is: 0.237
#
#
# ####################################### NUM_ROUNDS=2 #######################################
# We will simulate 2000 game each for 2 rounds. These games will be Aggressive player vs Random Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Random Player
# No of Rounds: 2, No of runs: 2000, Total time: 2.563 sec, Average time: 0.001 sec
# Aggressive won 1487 games out of 2000 games. Winning percentage is: 0.744
# Random Player won 513 games out of 2000 games. Winning percentage is: 0.257
#
#
# ####################################### NUM_ROUNDS=3 #######################################
# We will simulate 2000 game each for 3 rounds. These games will be Aggressive player vs Random Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Random Player
# No of Rounds: 3, No of runs: 2000, Total time: 4.673 sec, Average time: 0.002 sec
# Aggressive won 1531 games out of 2000 games. Winning percentage is: 0.765
# Random Player won 469 games out of 2000 games. Winning percentage is: 0.234
#
#
# ####################################### NUM_ROUNDS=4 #######################################
# We will simulate 2000 game each for 4 rounds. These games will be Aggressive player vs Random Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Random Player
# No of Rounds: 4, No of runs: 2000, Total time: 4.870 sec, Average time: 0.002 sec
# Aggressive won 1483 games out of 2000 games. Winning percentage is: 0.742
# Random Player won 517 games out of 2000 games. Winning percentage is: 0.259
#
#
# ####################################### NUM_ROUNDS=5 #######################################
# We will simulate 2000 game each for 5 rounds. These games will be Aggressive player vs Random Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Random Player
# No of Rounds: 5, No of runs: 2000, Total time: 6.982 sec, Average time: 0.003 sec
# Aggressive won 1407 games out of 2000 games. Winning percentage is: 0.704
# Random Player won 593 games out of 2000 games. Winning percentage is: 0.296
#
#
# ####################################### NUM_ROUNDS=6 #######################################
# We will simulate 2000 game each for 6 rounds. These games will be Aggressive player vs Random Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Random Player
# No of Rounds: 6, No of runs: 2000, Total time: 7.216 sec, Average time: 0.004 sec
# Aggressive won 1404 games out of 2000 games. Winning percentage is: 0.702
# Random Player won 596 games out of 2000 games. Winning percentage is: 0.298
#
#
# ####################################### NUM_ROUNDS=7 #######################################
# We will simulate 2000 game each for 7 rounds. These games will be Aggressive player vs Random Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Random Player
# No of Rounds: 7, No of runs: 2000, Total time: 9.316 sec, Average time: 0.005 sec
# Aggressive won 1368 games out of 2000 games. Winning percentage is: 0.684
# Random Player won 632 games out of 2000 games. Winning percentage is: 0.316
#
#
# ####################################### NUM_ROUNDS=8 #######################################
# We will simulate 2000 game each for 8 rounds. These games will be Aggressive player vs Random Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Random Player
# No of Rounds: 8, No of runs: 2000, Total time: 10.427 sec, Average time: 0.005 sec
# Aggressive won 1307 games out of 2000 games. Winning percentage is: 0.653
# Random Player won 693 games out of 2000 games. Winning percentage is: 0.346
#
#
# ####################################### NUM_ROUNDS=9 #######################################
# We will simulate 2000 game each for 9 rounds. These games will be Aggressive player vs Random Player
# Player 0 (GREEN Pieces) is Aggressive player. Player 2 (BLUE Pieces) is Random Player
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-4cd8830d94ab> in <cell line: 10>()
#      10 for i in range(1, 31):
#      11   print(f"####################################### NUM_ROUNDS={i} #######################################")
# ---> 12   winners, ranwin_per = GameSimulation(run_num=2000, num_round=i, print_each_result=False, game_type=0)
#      13   RANDOM_PERCENTAGE_LIST.append(ranwin_per)
#      14   print("\n")
#
# <ipython-input-7-4162868e3dee> in GameSimulation(run_num, num_round, print_each_result, game_type, gui, figure_size, wait_time, save_hist)
#      41           piece_to_move = player2.piece
#      42
# ---> 43       _, _, _, _, _, there_is_a_winner = g.answer_observation(piece_to_move)
#      44
#      45       if there_is_a_winner and GUI:
#
# /content/A-Reinforcement-Learning-Approach-to-Ludo/LUDOpy/ludopy/game_3dice.py in answer_observation(self, piece_to_move)
#     249
#     250         # Get the environment after the move
# --> 251         after_obs = self.__gen_observation(self.current_player, roll_dice=False, choose_dice=False)
#     252
#     253         # If it is the next players turn then change current_player
#
# /content/A-Reinforcement-Learning-Approach-to-Ludo/LUDOpy/ludopy/game_3dice.py in __gen_observation(self, player_idx, roll_dice, choose_dice)
#     120
#     121         # Get where the player's pieces are and the enemy's pieces are
# --> 122         player_pieces, enemy_pieces = self.get_pieces(player_idx)
#     123         self.current_enemys = enemy_pieces
#     124         # Check if the player is a winner
#
# /content/A-Reinforcement-Learning-Approach-to-Ludo/LUDOpy/ludopy/game_3dice.py in get_pieces(self, seen_from)
#      75             pieces = self.players[seen_from].get_pieces()
#      76             # Get where the enemy's piece are
# ---> 77             enemy_pieces = [self.players[e].get_pieces() for e in self.enemys_order[seen_from]]
#      78         return pieces, enemy_pieces
#      79
#
# /content/A-Reinforcement-Learning-Approach-to-Ludo/LUDOpy/ludopy/game_3dice.py in <listcomp>(.0)
#      75             pieces = self.players[seen_from].get_pieces()
#      76             # Get where the enemy's piece are
# ---> 77             enemy_pieces = [self.players[e].get_pieces() for e in self.enemys_order[seen_from]]
#      78         return pieces, enemy_pieces
#      79
#
# /content/A-Reinforcement-Learning-Approach-to-Ludo/LUDOpy/ludopy/player.py in get_pieces(self)
#     194         :rtype pieces: list
#     195         """
# --> 196         return np.copy(self.pieces)
#     197
#     198     def move_piece(self, piece, dice, enemys):
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in copy(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
rounds = np.arange(1, 31)
winning_percentage_random = RANDOM_PERCENTAGE_LIST
winning_percentage_aggressive = [1 - percentage for percentage in RANDOM_PERCENTAGE_LIST]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(rounds, winning_percentage_random)
ax[0].set_title("No of Rounds vs Winning percentage of Random Player")
ax[0].set_xlabel("No of Rounds")
ax[0].set_ylabel("Winning percentage of Random Player")

ax[1].plot(rounds, winning_percentage_aggressive)
ax[1].set_title("No of Rounds vs Winning percentage of Aggressive Player")
ax[1].set_xlabel("No of Rounds")
ax[1].set_ylabel("Winning percentage of Aggressive Player")
# Out:
# Text(0, 0.5, 'Winning percentage of Strategic Player')
